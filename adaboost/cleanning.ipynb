# %%
import pandas as pd
import numpy as np
import time
from datetime import date

import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv('train_filled.csv')

# %%
train.head()

# %%
train.shape
# Out:
# (4958347, 54)

# %%
dropped_set = train[train['booking_bool'] == 0].index

# %%
train.drop(dropped_set, inplace=True)

# %%
# missing value percents

# %%
table = []
for i in train.columns:
    total_null = train[i].isnull().sum()
    table.append([i, total_null, 100*total_null/len(train[i])])

# %%
missing_values_overview = pd.DataFrame(table, columns = ["Feature Name", "Total Null", "% Null"])
missing_values_overview.sort_values("% Null",ascending = False) # arrange features based on % Null
# Out:
#                    Feature Name  Total Null     % Null
# 30      comp1_rate_percent_diff      135883  98.188453
# 45      comp6_rate_percent_diff      135352  97.804755
# 28                   comp1_rate      135222  97.710817
# 29                    comp1_inv      135039  97.578582
# 39      comp4_rate_percent_diff      134606  97.265698
# 48      comp7_rate_percent_diff      133843  96.714358
# 43                   comp6_rate      130693  94.438182
# 44                    comp6_inv      130070  93.988005
# 37                   comp4_rate      129605  93.651998
# 5       visitor_hist_starrating      129302  93.433052
# 6          visitor_hist_adr_usd      129256  93.399812
# 38                    comp4_inv      128594  92.921454
# 46                   comp7_rate      128249  92.672158
# 47                    comp7_inv      127147  91.875858
# 36      comp3_rate_percent_diff      122832  88.757858
# 33      comp2_rate_percent_diff      120431  87.022906
# 51      comp8_rate_percent_diff      119263  86.178915
# 42      comp5_rate_percent_diff      112667  81.412674
# 34                   comp3_rate       93092  67.267866
# 35                    comp3_inv       89841  64.918708
# 49                   comp8_rate       82796  59.828022
# 50                    comp8_inv       80408  58.102464
# 31                   comp2_rate       79896  57.732495
# 32                    comp2_inv       76616  55.362382
# 53           gross_bookings_usd           0   0.000000
# 52                   click_bool           0   0.000000
# 40                   comp5_rate           0   0.000000
# 41                    comp5_inv           0   0.000000
# 0                    Unnamed: 0           0   0.000000
# 27                  random_bool           0   0.000000
# 1                       srch_id           0   0.000000
# 14    prop_log_historical_price           0   0.000000
# 2                     date_time           0   0.000000
# 3                       site_id           0   0.000000
# 4   visitor_location_country_id           0   0.000000
# 7               prop_country_id           0   0.000000
# 8                       prop_id           0   0.000000
# 9               prop_starrating           0   0.000000
# 10            prop_review_score           0   0.000000
# 11              prop_brand_bool           0   0.000000
# 12         prop_location_score1           0   0.000000
# 13         prop_location_score2           0   0.000000
# 15                     position           0   0.000000
# 26    orig_destination_distance           0   0.000000
# 16                    price_usd           0   0.000000
# 17               promotion_flag           0   0.000000
# 18          srch_destination_id           0   0.000000
# 19          srch_length_of_stay           0   0.000000
# 20          srch_booking_window           0   0.000000
# 21            srch_adults_count           0   0.000000
# 22          srch_children_count           0   0.000000
# 23              srch_room_count           0   0.000000
# 24     srch_saturday_night_bool           0   0.000000
# 25    srch_query_affinity_score           0   0.000000
# 54                 booking_bool           0   0.000000

# %%
# drop null values

# %%
train.drop(['comp1_rate_percent_diff', 'comp6_rate_percent_diff', 'comp1_rate', 'comp1_inv', 'comp4_rate_percent_diff'], axis = 1, inplace=True)

# %%
train.drop(['comp7_rate_percent_diff', 'comp6_rate', 'comp6_inv', 'comp4_rate', 'visitor_hist_starrating', 'visitor_hist_adr_usd'], axis = 1, inplace=True)

# %%
train.drop(['comp4_inv', 'comp7_rate', 'comp7_inv', 'comp3_rate_percent_diff', 'comp2_rate_percent_diff', 'comp8_rate_percent_diff', 'comp5_rate_percent_diff'], axis = 1, inplace=True)

# %%
train.drop(['comp3_rate', 'comp3_inv', 'comp8_rate', 'comp8_inv', 'comp2_rate', 'comp2_inv'], axis = 1, inplace=True)

# %%
train.shape
# Out:
# (138390, 31)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 138390 entries, 12 to 4958345
# Data columns (total 31 columns):
# Unnamed: 0                     138390 non-null int64
# srch_id                        138390 non-null int64
# date_time                      138390 non-null object
# site_id                        138390 non-null int64
# visitor_location_country_id    138390 non-null int64
# prop_country_id                138390 non-null int64
# prop_id                        138390 non-null int64
# prop_starrating                138390 non-null int64
# prop_review_score              138390 non-null float64
# prop_brand_bool                138390 non-null int64
# prop_location_score1           138390 non-null float64
# prop_location_score2           138390 non-null float64
# prop_log_historical_price      138390 non-null float64
# position                       138390 non-null int64
# price_usd                      138390 non-null float64
# promotion_flag                 138390 non-null int64
# srch_destination_id            138390 non-null int64
# srch_length_of_stay            138390 non-null int64
# srch_booking_window            138390 non-null int64
# srch_adults_count              138390 non-null int64
# srch_children_count            138390 non-null int64
# srch_room_count                138390 non-null int64
# srch_saturday_night_bool       138390 non-null int64
# srch_query_affinity_score      138390 non-null float64
# orig_destination_distance      138390 non-null float64
# random_bool                    138390 non-null int64
# comp5_rate                     138390 non-null float64
# comp5_inv                      138390 non-null float64
# click_bool                     138390 non-null int64
# gross_bookings_usd             138390 non-null float64
# booking_bool                   138390 non-null int64
# dtypes: float64(10), int64(20), object(1)
# memory usage: 33.8+ MB

# %%
train.head()
# Out:
#      Unnamed: 0  srch_id            date_time  site_id  \
# 12           12        1  2013-04-04 08:32:15       12
# 63           63        6  2013-06-05 12:27:51       14
# 68           68        8  2013-03-20 17:50:44        5
# 194         194       21  2013-02-18 17:16:25       15
# 211         211       25  2012-12-11 13:03:42        5
#
#      visitor_location_country_id  prop_country_id  prop_id  prop_starrating  \
# 12                           187              219    68914                2
# 63                           100              100   104251                3
# 68                           219              219    27669                3
# 194                           55              216    61662                3
# 211                          219              219    23228                4
#
#      prop_review_score  prop_brand_bool  ...  srch_room_count  \
# 12                 3.0                1  ...                1
# 63                 4.0                1  ...                1
# 68                 3.5                1  ...                1
# 194                3.5                0  ...                1
# 211                4.0                0  ...                1
#
#      srch_saturday_night_bool  srch_query_affinity_score  \
# 12                          1                   -18.2597
# 63                          0                   -53.9831
# 68                          0                   -21.8237
# 194                         0                   -20.2124
# 211                         0                   -16.0430
#
#      orig_destination_distance  random_bool  comp5_rate  comp5_inv  \
# 12                      264.06            1         0.0       -1.0
# 63                      264.06            0         1.0        1.0
# 68                      264.06            0         0.0        1.0
# 194                     264.06            0         1.0        1.0
# 211                     264.06            0         0.0        0.0
#
#      click_bool  gross_bookings_usd  booking_bool
# 12            1              114.29             1
# 63            1              162.38             1
# 68            1               96.41             1
# 194           1              222.58             1
# 211           1               47.10             1
#
# [5 rows x 31 columns]

# %%
train.drop(['Unnamed: 0'], axis = 1, inplace=True)

# %%
train.shape
# Out:
# (138390, 30)

# %%
def month(date):
    return int(date[5:7])
def year(date):
    return int(date[0:4])

# %%
train['year'] = train['date_time'].apply(year)
train['month'] = train['date_time'].apply(month)

# %%
train.drop(['date_time'], axis = 1, inplace=True)

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 138390 entries, 12 to 4958345
# Data columns (total 31 columns):
# srch_id                        138390 non-null int64
# site_id                        138390 non-null int64
# visitor_location_country_id    138390 non-null int64
# prop_country_id                138390 non-null int64
# prop_id                        138390 non-null int64
# prop_starrating                138390 non-null int64
# prop_review_score              138390 non-null float64
# prop_brand_bool                138390 non-null int64
# prop_location_score1           138390 non-null float64
# prop_location_score2           138390 non-null float64
# prop_log_historical_price      138390 non-null float64
# position                       138390 non-null int64
# price_usd                      138390 non-null float64
# promotion_flag                 138390 non-null int64
# srch_destination_id            138390 non-null int64
# srch_length_of_stay            138390 non-null int64
# srch_booking_window            138390 non-null int64
# srch_adults_count              138390 non-null int64
# srch_children_count            138390 non-null int64
# srch_room_count                138390 non-null int64
# srch_saturday_night_bool       138390 non-null int64
# srch_query_affinity_score      138390 non-null float64
# orig_destination_distance      138390 non-null float64
# random_bool                    138390 non-null int64
# comp5_rate                     138390 non-null float64
# comp5_inv                      138390 non-null float64
# click_bool                     138390 non-null int64
# gross_bookings_usd             138390 non-null float64
# booking_bool                   138390 non-null int64
# year                           138390 non-null int64
# month                          138390 non-null int64
# dtypes: float64(10), int64(21)
# memory usage: 33.8 MB

# %%
train.to_csv('train_cleaned.csv')

# %%
# building model

# %%
train = pd.read_csv('train_cleaned.csv')

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138390 entries, 0 to 138389
# Data columns (total 32 columns):
# Unnamed: 0                     138390 non-null int64
# srch_id                        138390 non-null int64
# site_id                        138390 non-null int64
# visitor_location_country_id    138390 non-null int64
# prop_country_id                138390 non-null int64
# prop_id                        138390 non-null int64
# prop_starrating                138390 non-null int64
# prop_review_score              138390 non-null float64
# prop_brand_bool                138390 non-null int64
# prop_location_score1           138390 non-null float64
# prop_location_score2           138390 non-null float64
# prop_log_historical_price      138390 non-null float64
# position                       138390 non-null int64
# price_usd                      138390 non-null float64
# promotion_flag                 138390 non-null int64
# srch_destination_id            138390 non-null int64
# srch_length_of_stay            138390 non-null int64
# srch_booking_window            138390 non-null int64
# srch_adults_count              138390 non-null int64
# srch_children_count            138390 non-null int64
# srch_room_count                138390 non-null int64
# srch_saturday_night_bool       138390 non-null int64
# srch_query_affinity_score      138390 non-null float64
# orig_destination_distance      138390 non-null float64
# random_bool                    138390 non-null int64
# comp5_rate                     138390 non-null float64
# comp5_inv                      138390 non-null float64
# click_bool                     138390 non-null int64
# gross_bookings_usd             138390 non-null float64
# booking_bool                   138390 non-null int64
# year                           138390 non-null int64
# month                          138390 non-null int64
# dtypes: float64(10), int64(22)
# memory usage: 33.8 MB

# %%
X = train.drop(['prop_id'], axis=1)
y = train['prop_id']

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 138390 entries, 0 to 138389
# Data columns (total 31 columns):
# Unnamed: 0                     138390 non-null int64
# srch_id                        138390 non-null int64
# site_id                        138390 non-null int64
# visitor_location_country_id    138390 non-null int64
# prop_country_id                138390 non-null int64
# prop_starrating                138390 non-null int64
# prop_review_score              138390 non-null float64
# prop_brand_bool                138390 non-null int64
# prop_location_score1           138390 non-null float64
# prop_location_score2           138390 non-null float64
# prop_log_historical_price      138390 non-null float64
# position                       138390 non-null int64
# price_usd                      138390 non-null float64
# promotion_flag                 138390 non-null int64
# srch_destination_id            138390 non-null int64
# srch_length_of_stay            138390 non-null int64
# srch_booking_window            138390 non-null int64
# srch_adults_count              138390 non-null int64
# srch_children_count            138390 non-null int64
# srch_room_count                138390 non-null int64
# srch_saturday_night_bool       138390 non-null int64
# srch_query_affinity_score      138390 non-null float64
# orig_destination_distance      138390 non-null float64
# random_bool                    138390 non-null int64
# comp5_rate                     138390 non-null float64
# comp5_inv                      138390 non-null float64
# click_bool                     138390 non-null int64
# gross_bookings_usd             138390 non-null float64
# booking_bool                   138390 non-null int64
# year                           138390 non-null int64
# month                          138390 non-null int64
# dtypes: float64(10), int64(21)
# memory usage: 32.7 MB

# %%
from sklearn.preprocessing import LabelEncoder
import keras
from keras.utils import np_utils

from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import LabelEncoder
# Out:
# Using TensorFlow backend.

# %%
encoder = LabelEncoder()
binary_encoded_y = pd.Series(encoder.fit_transform(y))

# %%
# X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
train_X, test_X, train_y, test_y = train_test_split(X, binary_encoded_y, test_size=0.2, random_state=1)

# %%
classifier = AdaBoostClassifier(
    DecisionTreeClassifier(max_depth=1), algorithm="SAMME",
                               n_estimators=200, learning_rate=0.8)

# %%
classifier.n_jobs = 3

# %%
classifier.fit(train_X, train_y)

# %%
predictions = classifier.predict(test_X)
confusion_matrix(test_y, predictions)
